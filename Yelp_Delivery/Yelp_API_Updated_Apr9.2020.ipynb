# %% [markdown]
# Client ID
# pcYg-P8c8BaI_ztBwaTGmw
#
# API Key
# 4MSriJZOVqZN2Qzr5VJv7ZNFM7XiPtcSA-EmXpB-Pp4eoJi-xfOoFNFHb2A6g0-TWApA6Xeieg9bL8erXqdvBlfnLCGJhnh8p8QEa_UWgKGrnSr4dJgOgNQDcPt7XnYx

# %%
#Dependencies
import pandas as pd
import requests
import numpy as np
import matplotlib.pyplot as plt
import geojson as gs
from ipyleaflet import Map, Marker, MarkerCluster
from IPython.core.display import display, HTML
import pymongo
from pymongo import MongoClient
print ('Mongo version', pymongo.__version__)
client = MongoClient('localhost', 27017)
db = client.test
collection = db.people
# Out:
# Mongo version 3.10.1

# %%
base_url = "https://api.yelp.com/v3/businesses/search"

# %%
yelp_headers = {
    "Authorization": "Bearer 4MSriJZOVqZN2Qzr5VJv7ZNFM7XiPtcSA-EmXpB-Pp4eoJi-xfOoFNFHb2A6g0-TWApA6Xeieg9bL8erXqdvBlfnLCGJhnh8p8QEa_UWgKGrnSr4dJgOgNQDcPt7XnYx"
}

# %% [markdown]
# ### Take Out & Delivery in San Francisco, CA

# %%
yelp_params = {
    "term": "delivery",
    "location": "San Francisco, CA", 
    "limit": 50,
    "radius": 20000   
}

# %%
#Perform API Key request.
response = requests.get(base_url, params=yelp_params, headers=yelp_headers)
response
# Out:
# <Response [200]>

# %%
sf_data = response.json()
sf_data
# Out:
# {'businesses': [{'id': 'lgD2BDiMtW3UhM6rk3IUNw',
#    'alias': 'chicken-as-cluck-san-francisco',
#    'name': 'Chicken as Cluck',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/lzHGEUlhlRCxWJD7LacVEg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chicken-as-cluck-san-francisco?adjust_creative=pcYg-P8c8BaI_ztBwaTGmw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=pcYg-P8c8BaI_ztBwaTGmw',
#    'review_count': 67,
#    'categories': [{'alias': 'chickenshop', 'title': 'Chicken Shop'},
#     {'alias': 'fooddeliveryservices', 'title': 'Food Delivery Services'},
#     {'alias': 'catering', 'title': 'Caterers'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.750541, 'longitude': -122.395028},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1760 Cesar Chavez St',
#     'address2': None,
#     'address3': None,
#     'city': 'San Francisco',
#     'zip_code': '94124',
# ...

# %% [markdown]
# ### API request using 'Transactions'

# %%
sf_transactions_base_url = "https://api.yelp.com/v3/transactions/delivery/search"

# %%
response = requests.get(sf_transactions_base_url, params=yelp_params, headers=yelp_headers)
response
# Out:
# <Response [200]>

# %%
sf_data = response.json()
sf_data
# Out:
# {'businesses': [{'id': 'ZD5-5Gu44WrcsYtw7qMgiw',
#    'alias': 'palmyra-san-francisco',
#    'name': 'Palmyra',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/utTINOJTETFlgcVojIL1Ew/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/palmyra-san-francisco?adjust_creative=pcYg-P8c8BaI_ztBwaTGmw&utm_campaign=yelp_api_v3&utm_medium=api_v3_transactions_search_delivery&utm_source=pcYg-P8c8BaI_ztBwaTGmw',
#    'review_count': 871,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'mideastern', 'title': 'Middle Eastern'},
#     {'alias': 'syrian', 'title': 'Syrian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.771851, 'longitude': -122.433937},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '700 Haight St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94117',
#     'country': 'US',
#     'state': 'CA',
# ...

# %%
sf_takeout_df = pd.DataFrame(sf_data['businesses'])
sf_takeout_df
# Out:
#                         id                                           alias  \
# 0   ZD5-5Gu44WrcsYtw7qMgiw                           palmyra-san-francisco
# 1   bf72ckc4mWwcpqoZiFfVHA                 elaines-kitchen-san-francisco-3
# 2   ZajCfjeJaHdakadUMYT9Dw                    golden-kim-tar-san-francisco
# 3   8-zW9T7u9L-TDVfJyLMOZw  royal-indian-cuisine-on-fillmore-san-francisco
# 4   gR9DTbKCvezQlqvD7_FzPw            north-india-restaurant-san-francisco
# 5   bD9oSfgoygPFW3Po4rZeZg                 mandarin-house-sf-san-francisco
# 6   0w6dNMrpBQFLxhVYqx_J5Q                          red-jade-san-francisco
# 7   4flzSf_EwBqeRb_3YT5VTg                       milan-pizza-san-francisco
# 8   OpBTLNaGnGcn8DRsLcEfQQ                          maykadeh-san-francisco
# 9   25KGeqGCQ2NGUT6217hF8Q                  amsterdam-café-san-francisco-2
# 10  QWZO1RdLbG5h0RGDiItoAA                   zaoh-restaurant-san-francisco
# ...

# %%
sf_takeout_df.to_csv("sf_takeout.csv", index=False)

# %% [markdown]
# ### Create SQLite file for San Francisco Take Outs

# %%
connection = "sqlite:///sf_takeout.sqlite"

# %%
sf_df = pd.read_sql("sf_takeout", con=connection)
sf_df
# Out:
#                         id                                           alias  \
# 0   ZD5-5Gu44WrcsYtw7qMgiw                           palmyra-san-francisco
# 1   8-zW9T7u9L-TDVfJyLMOZw  royal-indian-cuisine-on-fillmore-san-francisco
# 2   ZajCfjeJaHdakadUMYT9Dw                    golden-kim-tar-san-francisco
# 3   bf72ckc4mWwcpqoZiFfVHA                 elaines-kitchen-san-francisco-3
# 4   DAiqwrmv19Uv-I1bOoAJCQ                 baiano-pizzeria-san-francisco-3
# 5   9jW6WTeK3BrXuZKvHyqrsA                            newa-san-francisco-4
# 6   gR9DTbKCvezQlqvD7_FzPw            north-india-restaurant-san-francisco
# 7   9BxwybESMtcZsXBO0K-axA                          berber-san-francisco-4
# 8   0w6dNMrpBQFLxhVYqx_J5Q                          red-jade-san-francisco
# 9   1fgmqu-VXQ2QX1FII89g3g                        red-chilli-san-francisco
# 10  VHeDQKCT81P3i0edsMs9rw        nobhill-pizza-and-shawarma-san-francisco
# ...

# %% [markdown]
# ### Take-Out & Delivery in Daly City, CA

# %%
base_url = "https://api.yelp.com/v3/businesses/search"

# %%
yelp_headers = {
    "Authorization": "Bearer 4MSriJZOVqZN2Qzr5VJv7ZNFM7XiPtcSA-EmXpB-Pp4eoJi-xfOoFNFHb2A6g0-TWApA6Xeieg9bL8erXqdvBlfnLCGJhnh8p8QEa_UWgKGrnSr4dJgOgNQDcPt7XnYx"
}

# %%
yelp_params = {
    "term": "delivery",
    "location": "Daly City, CA", 
    "limit": 50,
    "radius": 20000
}

# %%
#Perform API Key request.
response = requests.get(base_url, params=yelp_params, headers=yelp_headers)
response
# Out:
# <Response [200]>

# %%
dc_data = response.json()
dc_data
# Out:
# {'businesses': [{'id': 'wk1R0R2atEs9w4jgeibWqg',
#    'alias': 'rice-n-roll-pacifica',
#    'name': 'Rice N Roll',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/cxGqmYmRvExL5A7Z1fW6HQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rice-n-roll-pacifica?adjust_creative=pcYg-P8c8BaI_ztBwaTGmw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=pcYg-P8c8BaI_ztBwaTGmw',
#    'review_count': 692,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'vegetarian', 'title': 'Vegetarian'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 37.6460435, 'longitude': -122.4716853},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '683 Manor Dr',
#     'address2': None,
#     'address3': '',
#     'city': 'Pacifica',
#     'zip_code': '94044',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['683 Manor Dr', 'Pacifica, CA 94044']},
# ...

# %%
dc_takeout_df = pd.DataFrame(dc_data['businesses'])
dc_takeout_df
# Out:
#                         id                                              alias  \
# 0   wk1R0R2atEs9w4jgeibWqg                               rice-n-roll-pacifica
# 1   lgD2BDiMtW3UhM6rk3IUNw                     chicken-as-cluck-san-francisco
# 2   4vt88GERVAr4ODzaXpSnoQ                                    luigis-pacifica
# 3   zHo0wp9hVdAj-AuZVjbD4Q                   krispy-krunchy-chicken-daly-city
# 4   zeAyrFZhpT2WUH6S92bmBA                           totos-pizzeria-san-bruno
# 5   5VdBW-nXKmZS1E6Dh5uMdQ                         seniores-pizza-san-bruno-4
# 6   oU5xNeRZ6jqgiTx9m7j0FQ                oasis-vietnamese-cuisine-pacifica-2
# 7   7DhNUWPZqt43Y0975s8RSw                           hanato-ramen-daly-city-2
# 8   9AczSWX37-qY3MYHHtJVtQ                             davids-bagels-pacifica
# 9   GwbM9M3c_ZlFSDo7WTGeag                                  wingstop-millbrae
# 10  8kck3-K4zYKTJbJko0JlXQ       farmhouse-kitchen-thai-cuisine-san-francisco
# ...

# %%
dc_takeout_df.to_csv("dc_takeout.csv", index=False)

# %% [markdown]
# ### Create SQLite for Daly City Take-Outs

# %%
dc_takeout_df = dc_takeout_df.astype(str)

# %%
dc_takeout_df.to_sql("dc_takeout_7", con=dc_connection)

# %%
dc_df = pd.read_sql("dc_takeout_2", con=dc_connection)
dc_df
# Out:
#     index                      id  \
# 0       0  wk1R0R2atEs9w4jgeibWqg
# 1       1  lgD2BDiMtW3UhM6rk3IUNw
# 2       2  zHo0wp9hVdAj-AuZVjbD4Q
# 3       3  4vt88GERVAr4ODzaXpSnoQ
# 4       4  zeAyrFZhpT2WUH6S92bmBA
# 5       5  5VdBW-nXKmZS1E6Dh5uMdQ
# 6       6  oU5xNeRZ6jqgiTx9m7j0FQ
# 7       7  9AczSWX37-qY3MYHHtJVtQ
# 8       8  GwbM9M3c_ZlFSDo7WTGeag
# 9       9  8kck3-K4zYKTJbJko0JlXQ
# 10     10  ItRA_StAZd9xxrQCozhW3A
# 11     11  lXMdrPSUmA9HfoHosOvzbQ
# 12     12  vOkiTLs9MVLx6_jtIjT-GA
# 13     13  UOForEkDjUF4tTB1ZBL5MA
# 14     14  7DhNUWPZqt43Y0975s8RSw
# 15     15  kKm6pi-NazSJArAyVNH7RA
# 16     16  8dPFvqiYz4ZJUY4DZqZo1Q
# 17     17  evyJ3otVH3fxBN9d9YjuXg
# 18     18  Lr0ThGKRi6BxWCiry3Y4sw
# 19     19  cIQu_DxZkmRA5gJNvrYoCA
# 20     20  gcdiumG5hmCUyYWe6sWMTg
# 21     21  -3vWq_Ei0K52mywpiXdnag
# 22     22  xyep0zfjLgmNvaxxOvOfag
# 23     23  Ws0RhWUoZcbvqD--Qrp57w
# 24     24  6Ybsq0oIPb1vz5czq0_y7w
# 25     25  EtvpRSw6cZzJt7AzpfJj8g
# ...

# %%
dc_connection = "sqlite:///dc_takeout.sqlite"

# %% [markdown]
# ### Take Out and Delivery in San Bruno, CA

# %%
base_url = "https://api.yelp.com/v3/businesses/search"

# %%
yelp_headers = {
    "Authorization": "Bearer 4MSriJZOVqZN2Qzr5VJv7ZNFM7XiPtcSA-EmXpB-Pp4eoJi-xfOoFNFHb2A6g0-TWApA6Xeieg9bL8erXqdvBlfnLCGJhnh8p8QEa_UWgKGrnSr4dJgOgNQDcPt7XnYx"
}

# %%
yelp_params = {
    "term": "delivery",
    "location": "San Bruno, CA", 
    "limit": 50,
    "radius": 20000
}

# %%
#Perform API Key request.
response = requests.get(base_url, params=yelp_params, headers=yelp_headers)
response
# Out:
# <Response [200]>

# %%
sbr_data = response.json()
sbr_data
# Out:
# {'businesses': [{'id': '5VdBW-nXKmZS1E6Dh5uMdQ',
#    'alias': 'seniores-pizza-san-bruno-4',
#    'name': "Seniore's Pizza",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/r7M5LEWQVKxJ9qb7A0mScg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/seniores-pizza-san-bruno-4?adjust_creative=pcYg-P8c8BaI_ztBwaTGmw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=pcYg-P8c8BaI_ztBwaTGmw',
#    'review_count': 317,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 37.627449, 'longitude': -122.416373},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '730 Kains Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'San Bruno',
#     'zip_code': '94066',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['730 Kains Ave', 'San Bruno, CA 94066']},
#    'phone': '+16509524100',
# ...

# %%
sbr_takeout_df = pd.DataFrame(sbr_data['businesses'])
sbr_takeout_df
# Out:
#                         id                                              alias  \
# 0   5VdBW-nXKmZS1E6Dh5uMdQ                         seniores-pizza-san-bruno-4
# 1   vOkiTLs9MVLx6_jtIjT-GA                              zorbas-pizza-millbrae
# 2   GwbM9M3c_ZlFSDo7WTGeag                                  wingstop-millbrae
# 3   zeAyrFZhpT2WUH6S92bmBA                           totos-pizzeria-san-bruno
# 4   wk1R0R2atEs9w4jgeibWqg                               rice-n-roll-pacifica
# 5   8dPFvqiYz4ZJUY4DZqZo1Q                    hidden-spot-south-san-francisco
# 6   zsBCkBlCp-anXtyC5NcNTg                        boiling-beijing-san-bruno-5
# 7   Ws0RhWUoZcbvqD--Qrp57w            e-plus-restaurant-south-san-francisco-3
# 8   ZtTU1nouWYzqGmIbxp53oQ                           new-york-pizza-san-bruno
# 9   ObxYfb71k4YZO4JB9XUuVw                 big-belly-deli-south-san-francisco
# 10  zHo0wp9hVdAj-AuZVjbD4Q                   krispy-krunchy-chicken-daly-city
# ...

# %%
sbr_takeout_df.to_csv("sb_takeout.csv", index=False)

# %% [markdown]
# ### Create SQLite for San Bruno Take-Outs

# %%
sbr_takeout_df = sbr_takeout_df.astype(str)

# %%
sbr_takeout_df.to_sql("sbr_takeout_11", con=sbr_connection)

# %%
sbr_connection = "sqlite:///sbr_takeout.sqlite"

# %% [markdown]
# ### Take Out & Delivery in South San Francisco

# %%
base_url = "https://api.yelp.com/v3/businesses/search"

# %%
yelp_headers = {
    "Authorization": "Bearer 4MSriJZOVqZN2Qzr5VJv7ZNFM7XiPtcSA-EmXpB-Pp4eoJi-xfOoFNFHb2A6g0-TWApA6Xeieg9bL8erXqdvBlfnLCGJhnh8p8QEa_UWgKGrnSr4dJgOgNQDcPt7XnYx"
}

# %%
yelp_params = {
    "term": "delivery",
    "location": "South San Francisco, CA", 
    "limit": 50,
    "radius": 20000   
}

# %%
#Perform API Key request.
response = requests.get(base_url, params=yelp_params, headers=yelp_headers)
response
# Out:
# <Response [200]>

# %%
ssf_data = response.json()
ssf_data
# Out:
# {'businesses': [{'id': '8kck3-K4zYKTJbJko0JlXQ',
#    'alias': 'farmhouse-kitchen-thai-cuisine-san-francisco',
#    'name': 'Farmhouse Kitchen Thai Cuisine',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/woO06sua7uMQNBf0wnjf8w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/farmhouse-kitchen-thai-cuisine-san-francisco?adjust_creative=pcYg-P8c8BaI_ztBwaTGmw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=pcYg-P8c8BaI_ztBwaTGmw',
#    'review_count': 2422,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'comfortfood', 'title': 'Comfort Food'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.76026094, 'longitude': -122.4112048},
#    'transactions': ['delivery', 'pickup', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '710 Florida St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94110',
#     'country': 'US',
# ...

# %%
ssf_takeout_df = pd.DataFrame(ssf_data['businesses'])
ssf_takeout_df
# Out:
#                         id                                              alias  \
# 0   8kck3-K4zYKTJbJko0JlXQ       farmhouse-kitchen-thai-cuisine-san-francisco
# 1   ru2orVI8tiNoYAPggtNHmw                   siam-spoon-south-san-francisco-2
# 2   lgD2BDiMtW3UhM6rk3IUNw                     chicken-as-cluck-san-francisco
# 3   zHo0wp9hVdAj-AuZVjbD4Q                   krispy-krunchy-chicken-daly-city
# 4   ObxYfb71k4YZO4JB9XUuVw                 big-belly-deli-south-san-francisco
# 5   ItRA_StAZd9xxrQCozhW3A                                 jollibee-daly-city
# 6   cIQu_DxZkmRA5gJNvrYoCA                                yangon-burlingame-2
# 7   iEk34XVa-aOOwjlw2GT4Bw  dinapoli-ristorante-and-pizzeria-south-san-fra...
# 8   vOkiTLs9MVLx6_jtIjT-GA                              zorbas-pizza-millbrae
# 9   zeAyrFZhpT2WUH6S92bmBA                           totos-pizzeria-san-bruno
# 10  z3vreTWRWKBqUCJD4lxuDg               sweet-basil-thai-cuisine-foster-city
# ...

# %%
ssf_takeout_df.to_csv("sb_takeout.csv", index=False)

# %% [markdown]
# ### Create SQLite File for South San Francisco Take-Outs

# %%
ssf_takeout_df = ssf_takeout_df.astype(str)

# %%
ssf_takeout_df.to_sql("ssf_takeout_11", con=ssf_connection)

# %%
ssf_connection = "sqlite:///ssf_takeout.sqlite"

# %% [markdown]
# ### Take Out & Delivery in Millbrae

# %%
base_url = "https://api.yelp.com/v3/businesses/search"

# %%
yelp_headers = {
    "Authorization": "Bearer 4MSriJZOVqZN2Qzr5VJv7ZNFM7XiPtcSA-EmXpB-Pp4eoJi-xfOoFNFHb2A6g0-TWApA6Xeieg9bL8erXqdvBlfnLCGJhnh8p8QEa_UWgKGrnSr4dJgOgNQDcPt7XnYx"
}

# %%
yelp_params = {
    "term": "delivery",
    "location": "Millbrae, CA", 
    "limit": 50,
    "radius": 20000   
}

# %%
#Perform API Key request.
response = requests.get(base_url, params=yelp_params, headers=yelp_headers)
response
# Out:
# <Response [200]>

# %%
mlbr_data = response.json()
mlbr_data
# Out:
# {'businesses': [{'id': 'zHo0wp9hVdAj-AuZVjbD4Q',
#    'alias': 'krispy-krunchy-chicken-daly-city',
#    'name': 'Krispy Krunchy Chicken',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/SgAthVrNiKGV50OQMUkcTw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/krispy-krunchy-chicken-daly-city?adjust_creative=pcYg-P8c8BaI_ztBwaTGmw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=pcYg-P8c8BaI_ztBwaTGmw',
#    'review_count': 102,
#    'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#     {'alias': 'chicken_wings', 'title': 'Chicken Wings'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.68315, 'longitude': -122.48991},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '505 Skyline Dr',
#     'address2': '',
#     'address3': None,
#     'city': 'Daly City',
#     'zip_code': '94015',
#     'country': 'US',
#     'state': 'CA',
# ...

# %%
mlbr_takeout_df = pd.DataFrame(mlbr_data['businesses'])
mlbr_takeout_df
# Out:
#                         id                                              alias  \
# 0   zHo0wp9hVdAj-AuZVjbD4Q                   krispy-krunchy-chicken-daly-city
# 1   vOkiTLs9MVLx6_jtIjT-GA                              zorbas-pizza-millbrae
# 2   ItRA_StAZd9xxrQCozhW3A                                 jollibee-daly-city
# 3   GwbM9M3c_ZlFSDo7WTGeag                                  wingstop-millbrae
# 4   5VdBW-nXKmZS1E6Dh5uMdQ                         seniores-pizza-san-bruno-4
# 5   zeAyrFZhpT2WUH6S92bmBA                           totos-pizzeria-san-bruno
# 6   8kck3-K4zYKTJbJko0JlXQ       farmhouse-kitchen-thai-cuisine-san-francisco
# 7   v1A0oR_u7THCZ8IX-crIFg                     verrazzano-pizza-half-moon-bay
# 8   UT3eod0jmPmT_Iwuz45Drg                       porridge-and-things-millbrae
# 9   0goz5_BBAc0hltKtxd4nkw  jersey-joes-coastside-hoagies-and-cheesesteaks...
# 10  MpwQAOTvW4MLE_smNHZxxw                              earl-spicy-millbrae-4
# ...

# %%
mlbr_takeout_df.to_csv("mlbr_takeout.csv", index=False)

# %% [markdown]
# ### Create SQLite File for Millbrae Take-Outs

# %%
mlbr_takeout_df = mlbr_takeout_df.astype(str)

# %%
mlbr_takeout_df.to_sql("mlbr_takeout_2", con=mlbr_connection)

# %%
mlbr_connection = "sqlite:///mlbr_takeout.sqlite"
